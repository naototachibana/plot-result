# %% [markdown]
# # 結果をプロットするプログラム

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

class simple_plot :
    def __init__(self, df_obs,df_pred):
        self.df_obs = df_obs
        self.df_pred = df_pred
        self.obs = df_obs.values
        self.pred = df_pred.values
        self.xlabel = df_obs.name
        self.ylabel = df_pred.name
        self.ymin = np.amin(self.pred)
        self.ymax = np.amax(self.pred)
        self.yrange = self.ymax - self.ymin
        self.fig = None
        self.RMSE = None
        self.R2 = None
        self.label_message = None
        self.xlabel = None
        self.ylabel = None
        
    def update_range(self,df_obs, df_pred):
        if (self.ymax < np.amax(df_pred.values)):
            self.ymax = np.amax(df_pred.values)
            
        if (self.ymin > np.amin(df_pred.values)):
            self.ymin = np.amin(df_pred.values)
        self.yrange = self.ymax - self.ymin
    
    def plot (self):
        self.fig = plt.figure(figsize=(8, 8))
        

        plt.plot([self.ymin - self.yrange * 0.01, self.ymax + self.yrange * 0.01], 
                 [self.ymin - self.yrange * 0.01, self.ymax + self.yrange * 0.01])

        plt.xlim(self.ymin - self.yrange * 0.01,
             self.ymax + self.yrange * 0.01)

        plt.ylim(self.ymin - self.yrange * 0.01,
             self.ymax + self.yrange * 0.01)
        
        self.RMSE = np.sqrt(mean_squared_error(self.df_obs, self.df_pred))
        self.R2 = r2_score(self.df_obs, self.df_pred)
        self.label_message = ("RMSE : " + str (round(self.RMSE, 5))
                  +"\nR2      : "+ str(round(self.R2, 5)))
        
        plt.scatter(self.obs, self.pred, label=self.label_message)
        plt.legend(fontsize=12, loc='upper left')
        self.xlabel = self.df_obs.name
        self.ylabel = self.df_pred.name
        plt.xlabel(self.xlabel, fontsize=24)
        plt.ylabel(self.ylabel, fontsize=24)
        plt.title('Observed-Predicted Plot', fontsize=24)
        plt.tick_params(labelsize=16)
        plt.grid()
        self.fig.show()

# %%
filepath = "/Users/user/programs/result_dnn_lowest/eval_GAP/eval_GAP_hartree_lowest_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_GAP/eval_GAP_hartree_lowest_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_GAP/eval_GAP_hartree_lowest_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_GAP_hartree"
pred_column_name = "predicted_GAP_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
filepath = "/Users/user/programs/result_dnn_lowest/eval_HOMO/eval_HOMO_hartree_lowest_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_HOMO/eval_HOMO_hartree_lowest_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_HOMO/eval_HOMO_hartree_lowest_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_HOMO_hartree"
pred_column_name = "predicted_HOMO_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
filepath = "/Users/user/programs/result_dnn_lowest/eval_LUMO/eval_LUMO_hartree_lowest_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_LUMO/eval_LUMO_hartree_lowest_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_LUMO/eval_LUMO_hartree_lowest_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_LUMO_hartree"
pred_column_name = "predicted_LUMO_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
filepath = "/Users/user/programs/result_dnn_lowest/eval_total_energy/eval_total_energy_hartree_lowest_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_total_energy/eval_total_energy_hartree_lowest_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_lowest/eval_total_energy/eval_total_energy_hartree_lowest_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "t_total_energy_hartree"
pred_column_name = "pred_total_energy_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
#y_pred_energy t_energy
filepath = "/Users/user/programs/lab_results/results_3d-morse_lowest/eval_HOMO_lowest_HOMOLUMO_morse_train1_all.csv/out_pred_target_cid.csv"
filename = os.path.basename(filepath)
df = pd.read_csv (filepath)
print (str(df.columns))
fig, RMSE, R2 = yyplot(df_obs = df["t_HOMO"],
                       df_pred = df["pred_HOMO"],)
fig.show()
print(filepath)

# %%
#y_pred_energy t_energy
filepath = "/Users/user/programs/lab_results/results_3d-morse_lowest/eval_LUMO_lowest_HOMOLUMO_morse_train1_all.csv/out_pred_target_cid.csv"
filename = os.path.basename(filepath)
df = pd.read_csv (filepath)
print (str(df.columns))
fig, RMSE, R2 = yyplot(df_obs = df["t_LUMO"],
                       df_pred = df["pred_LUMO"],)
fig.show()
print(filepath)
