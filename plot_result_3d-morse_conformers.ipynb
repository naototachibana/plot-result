# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import re
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

class simple_plot :
    def __init__(self, df_obs,df_pred, xlabel = None, ylabel = None):
        self.df_obs = df_obs
        self.df_pred = df_pred
        self.obs = df_obs.values
        self.pred = df_pred.values
        self.xlabel = df_obs.name
        self.ylabel = df_pred.name
        self.ymin = min (np.amin(self.pred), np.amin(self.obs))
        self.ymax = max (np.amax(self.pred), np.amax(self.obs))
        self.yrange = self.ymax - self.ymin
        self.fig = None
        self.RMSE = None
        self.R2 = None
        self.label_message = None
        self.xlabel = self.df_obs.name
        self.ylabel = self.df_pred.name
        
    def update_range(self,df_obs, df_pred):
        if (self.ymax < np.amax(df_pred.values)):
            self.ymax = np.amax(df_pred.values)
            
        if (self.ymin > np.amin(df_pred.values)):
            self.ymin = np.amin(df_pred.values)
        self.yrange = self.ymax - self.ymin
    
    def report_max (self):
        return self.ymax
    def report_min (self):
        return self.ymin
    
    def plot (self, energy_max, energy_min):
        self.fig = plt.figure(figsize=(8, 8))
        self.yrange = energy_max - energy_min
        xmin = energy_min - self.yrange * 0.01
        xmax = energy_max + self.yrange * 0.01
        ymin = energy_min- self.yrange * 0.01
        ymax = energy_max + self.yrange * 0.01
        plt.plot([xmin, xmax], 
                 [ymin, ymax])

        plt.xlim(xmin,xmax)

        plt.ylim(ymin,ymax)
        self.RMSE = np.sqrt(mean_squared_error(self.df_obs, self.df_pred))
        self.R2 = r2_score(self.df_obs, self.df_pred)
        self.label_message = ("RMSE : " + str (round(self.RMSE, 5))
                  +"\nR2      : "+ str(round(self.R2, 5)))
        
        plt.scatter(self.obs, self.pred, label=self.label_message)
        plt.legend(fontsize=12, loc='upper left')

        plt.xlabel(self.xlabel, fontsize=24)
        plt.ylabel(self.ylabel, fontsize=24)
        plt.title('Observed-Predicted Plot', fontsize=24)
        plt.tick_params(labelsize=16)
        plt.grid()
        self.fig.show()

# %%
filepath = "/Users/user/programs/result_dnn_conformers/eval_total_energy/eval_total_energy_hartree_conformers_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_total_energy/eval_total_energy_hartree_conformers_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_total_energy/eval_total_energy_hartree_conformers_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_total_energy_hartree"
pred_column_name = "predicted_total_energy_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )

energy_max = max(energy_loewest_plot1.report_max(),
                 energy_loewest_plot2.report_max(),
                 energy_loewest_plot3.report_max())
energy_min = min(energy_loewest_plot1.report_min(),
                 energy_loewest_plot2.report_min(),
                 energy_loewest_plot3.report_min())
print(energy_max, energy_min)
energy_loewest_plot1.plot(energy_max, energy_min)
energy_loewest_plot2.plot(energy_max, energy_min)
energy_loewest_plot3.plot(energy_max, energy_min)
# Out:
# -40.03586196899414 -996.992919921875
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
filepath = "/Users/user/programs/result_dnn_conformers/eval_total_energy/eval_total_energy_hartree_conformers_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_total_energy/eval_total_energy_hartree_conformers_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_total_energy/eval_total_energy_hartree_conformers_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_total_energy_hartree"
pred_column_name = "predicted_total_energy_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()
# Out:
# observed_total_energy_hartree
# xmin, xmax : -916.9119832992553-31.35392017364502
# predicted_total_energy_hartree
# ymin, ymax : -916.9119832992553-31.35392017364502
# observed_total_energy_hartree
# xmin, xmax : -957.043517112732-30.956578254699707
# predicted_total_energy_hartree
# ymin, ymax : -957.043517112732-30.956578254699707
# observed_total_energy_hartree
# xmin, xmax : -1006.5624905014038-30.466291389465333
# predicted_total_energy_hartree
# ymin, ymax : -1006.5624905014038-30.466291389465333
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
filepath = "/Users/user/programs/result_dnn_conformers/eval_HOMO/eval_HOMO_hartree_conformers_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_HOMO/eval_HOMO_hartree_conformers_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_HOMO/eval_HOMO_hartree_conformers_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_HOMO_hartree"
pred_column_name = "predicted_HOMO_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()

# %%
filepath = "/Users/user/programs/result_dnn_conformers/eval_LUMO/eval_LUMO_hartree_conformers_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_LUMO/eval_LUMO_hartree_conformers_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_LUMO/eval_LUMO_hartree_conformers_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_LUMO_hartree"
pred_column_name = "predicted_LUMO_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()

# %%
filepath = "/Users/user/programs/result_dnn_conformers/eval_GAP/eval_GAP_hartree_conformers_0_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df1 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_GAP/eval_GAP_hartree_conformers_1_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df2 = pd.read_csv (filepath)

filepath = "/Users/user/programs/result_dnn_conformers/eval_GAP/eval_GAP_hartree_conformers_2_2000epoch/observed_and_predicted.csv"
filename = os.path.basename(filepath)
df3 = pd.read_csv (filepath)

obs_column_name = "observed_GAP_hartree"
pred_column_name = "predicted_GAP_hartree"
energy_loewest_plot1 = simple_plot (df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot1.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot1.plot()

energy_loewest_plot2 = simple_plot (df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot2.update_range(df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot2.plot()

energy_loewest_plot3 = simple_plot (df_obs = df3[obs_column_name], df_pred = df3[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df2[obs_column_name], df_pred = df2[pred_column_name] )
energy_loewest_plot3.update_range(df_obs = df1[obs_column_name], df_pred = df1[pred_column_name] )
energy_loewest_plot3.plot()
